# %%
#!pip install lightkurve

# %% [markdown]
# ## r1_correctLC

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from astropy.table import Table
from lightkurve import LightCurve
import astropy.units as u
import logging
#import batman-package as batman
#batman = __import__("batman-package")
import matplotlib
#from basic_functions import stop

logging.basicConfig(format='%(asctime)s %(levelname)s: %(name)s(%(funcName)s): %(message)s', level=logging.DEBUG)

import tessutils #NOT the normal utils!

#dataDir = "data"
#downloadDir = "mastDownload/TESS"
#outdir = "results_notCorrectedForSineLong"
#correctSine = False

###################################################################################################
# Out:
# 2019-11-10 16:45:59,854 DEBUG: matplotlib.pyplot(switch_backend): Loaded backend module://ipykernel.pylab.backend_inline version unknown.

# %%
import matplotlib.pyplot as plt
from astropy.table import Table
import astropy.units as u
from astropy.io import fits 
import os
from lightkurve import LightCurve
import numpy as np
import requests
import gzip 
import pickle

import logging
logger = logging.getLogger(__name__)

import subprocess
from matplotlib import rc

import os
import shutil

# %%
lc = None
folderName = 'tess2018206045859-s0001-0000000092352620-0120-s'
downloadDir = 'CleanPath/LowMags/TIC_92352620/' #Path must flow like this

lc, sectors = tessutils.loadLC(folderName, downloadDir, fluxType="PDCSAP", normalised=True)
lcOri = lc.copy()

# Show what it looks like
plt.figure()
plt.scatter(lc.time, lc.flux, label="LC", marker='.', s=5)
lcB = lc.bin(100, method="median")
plt.scatter(lcB.time, lcB.flux, label="LC", marker='.', s=5)
plt.savefig(os.path.join(downloadDir, "TIC_92352620_raw.pdf"))
plt.show()
# Out:
# 2019-11-10 16:45:59,942 INFO: tessutils(loadLC): Cadence is 2 min for CleanPath/LowMags/TIC_92352620/tess2018206045859-s0001-0000000092352620-0120-s\tess2018206045859-s0001-0000000092352620-0120-s_lc.fits
# D:\Python\Anaconda\lib\site-packages\lightkurve\lightcurve.py:108: LightkurveWarning: LightCurve object contains NaN times
#   warnings.warn('LightCurve object contains NaN times', LightkurveWarning)
# 2019-11-10 16:46:00,371 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: Matching :family=sans-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0.
# 2019-11-10 16:46:00,372 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'cmtt10' (cmtt10.ttf) normal normal 400 normal>) = 10.05
# 2019-11-10 16:46:00,373 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-Bold.ttf) normal normal bold normal>) = 10.335
# 2019-11-10 16:46:00,374 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'cmex10' (cmex10.ttf) normal normal 400 normal>) = 10.05
# 2019-11-10 16:46:00,375 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'DejaVu Sans' (DejaVuSans-Bold.ttf) normal normal bold normal>) = 0.33499999999999996
# 2019-11-10 16:46:00,376 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'STIXNonUnicode' (STIXNonUniIta.ttf) italic normal 400 normal>) = 11.05
# 2019-11-10 16:46:00,376 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'cmsy10' (cmsy10.ttf) normal normal 400 normal>) = 10.05
# 2019-11-10 16:46:00,377 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'cmmi10' (cmmi10.ttf) normal normal 400 normal>) = 10.05
# 2019-11-10 16:46:00,378 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'cmss10' (cmss10.ttf) normal normal 400 normal>) = 10.05
# 2019-11-10 16:46:00,379 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'STIXNonUnicode' (STIXNonUniBol.ttf) normal normal bold normal>) = 10.335
# 2019-11-10 16:46:00,380 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-Bold.ttf) normal normal bold normal>) = 10.335
# 2019-11-10 16:46:00,380 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'DejaVu Sans Display' (DejaVuSansDisplay.ttf) normal normal 400 normal>) = 10.05
# 2019-11-10 16:46:00,381 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'STIXSizeFiveSym' (STIXSizFiveSymReg.ttf) normal normal regular normal>) = 10.05
# 2019-11-10 16:46:00,382 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'STIXSizeOneSym' (STIXSizOneSymReg.ttf) normal normal regular normal>) = 10.05
# 2019-11-10 16:46:00,384 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-BoldOblique.ttf) oblique normal bold normal>) = 11.335
# 2019-11-10 16:46:00,387 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'STIXGeneral' (STIXGeneralBol.ttf) normal normal bold normal>) = 10.335
# 2019-11-10 16:46:00,389 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'STIXGeneral' (STIXGeneral.ttf) normal normal regular normal>) = 10.05
# 2019-11-10 16:46:00,390 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'DejaVu Sans' (DejaVuSans.ttf) normal normal 400 normal>) = 0.05
# 2019-11-10 16:46:00,391 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'DejaVu Serif Display' (DejaVuSerifDisplay.ttf) normal normal 400 normal>) = 10.05
# 2019-11-10 16:46:00,392 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'STIXNonUnicode' (STIXNonUniBolIta.ttf) italic normal bold normal>) = 11.335
# 2019-11-10 16:46:00,393 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'STIXSizeThreeSym' (STIXSizThreeSymBol.ttf) normal normal bold normal>) = 10.335
# 2019-11-10 16:46:00,394 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'STIXGeneral' (STIXGeneralBolIta.ttf) italic normal bold normal>) = 11.335
# 2019-11-10 16:46:00,395 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'STIXSizeTwoSym' (STIXSizTwoSymBol.ttf) normal normal bold normal>) = 10.335
# 2019-11-10 16:46:00,397 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono.ttf) normal normal 400 normal>) = 10.05
# 2019-11-10 16:46:00,398 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'STIXSizeFourSym' (STIXSizFourSymBol.ttf) normal normal bold normal>) = 10.335
# 2019-11-10 16:46:00,399 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'cmr10' (cmr10.ttf) normal normal 400 normal>) = 10.05
# 2019-11-10 16:46:00,400 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-Italic.ttf) italic normal 400 normal>) = 11.05
# 2019-11-10 16:46:00,401 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'DejaVu Serif' (DejaVuSerif.ttf) normal normal 400 normal>) = 10.05
# 2019-11-10 16:46:00,401 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'STIXNonUnicode' (STIXNonUni.ttf) normal normal regular normal>) = 10.05
# 2019-11-10 16:46:00,403 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-Oblique.ttf) oblique normal 400 normal>) = 11.05
# 2019-11-10 16:46:00,404 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'STIXSizeOneSym' (STIXSizOneSymBol.ttf) normal normal bold normal>) = 10.335
# 2019-11-10 16:46:00,405 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'DejaVu Sans' (DejaVuSans-BoldOblique.ttf) oblique normal bold normal>) = 1.335
# 2019-11-10 16:46:00,405 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-BoldItalic.ttf) italic normal bold normal>) = 11.335
# 2019-11-10 16:46:00,406 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'DejaVu Sans' (DejaVuSans-Oblique.ttf) oblique normal 400 normal>) = 1.05
# 2019-11-10 16:46:00,407 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'cmb10' (cmb10.ttf) normal normal 400 normal>) = 10.05
# 2019-11-10 16:46:00,408 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'STIXGeneral' (STIXGeneralItalic.ttf) italic normal 400 normal>) = 11.05
# 2019-11-10 16:46:00,409 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'STIXSizeFourSym' (STIXSizFourSymReg.ttf) normal normal regular normal>) = 10.05
# 2019-11-10 16:46:00,413 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'STIXSizeTwoSym' (STIXSizTwoSymReg.ttf) normal normal regular normal>) = 10.05
# 2019-11-10 16:46:00,414 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'STIXSizeThreeSym' (STIXSizThreeSymReg.ttf) normal normal regular normal>) = 10.05
# 2019-11-10 16:46:00,415 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'Palatino Linotype' (palai.ttf) italic normal 400 normal>) = 11.05
# 2019-11-10 16:46:00,416 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'Copperplate Gothic Light' (COPRGTL.TTF) normal normal light normal>) = 10.24
# 2019-11-10 16:46:00,417 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'Ink Free' (Inkfree.ttf) normal normal 400 normal>) = 10.05
# 2019-11-10 16:46:00,418 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'Nirmala UI' (NirmalaS.ttf) normal normal light normal>) = 10.24
# 2019-11-10 16:46:00,422 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'Microso
TTF) normal normal bold normal>) = 10.335
# 2019-11-10 16:46:00,788 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'Trebuchet MS' (trebucbd.ttf) normal normal bold normal>) = 10.335
# 2019-11-10 16:46:00,789 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'French Script MT' (FRSCRIPT.TTF) normal normal 400 normal>) = 10.05
# 2019-11-10 16:46:00,790 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'Century Gothic' (GOTHICB.TTF) normal normal bold normal>) = 10.335
# 2019-11-10 16:46:00,791 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'Bell MT' (BELLB.TTF) normal normal bold normal>) = 10.335
# 2019-11-10 16:46:00,792 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'Microsoft New Tai Lue' (ntailu.ttf) normal normal 400 normal>) = 10.05
# 2019-11-10 16:46:00,794 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'Courier New' (cour.ttf) normal normal 400 normal>) = 10.05
# 2019-11-10 16:46:00,795 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'Yu Gothic' (YuGothL.ttc) normal normal light normal>) = 10.24
# 2019-11-10 16:46:00,796 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'Lucida Sans Typewriter' (LTYPEB.TTF) normal normal bold normal>) = 10.335
# 2019-11-10 16:46:00,797 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'Arial' (ARIALN.TTF) normal normal 400 condensed>) = 6.613636363636363
# 2019-11-10 16:46:00,798 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'OCR A Extended' (OCRAEXT.TTF) normal normal 400 normal>) = 10.05
# 2019-11-10 16:46:00,799 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'Tahoma' (tahomabd.ttf) normal normal bold normal>) = 10.335
# 2019-11-10 16:46:00,800 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'Garamond' (GARA.TTF) normal normal 400 normal>) = 10.05
# 2019-11-10 16:46:00,801 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'Adobe Devanagari' (AdobeDevanagari-Italic.otf) italic normal 400 normal>) = 11.05
# 2019-11-10 16:46:00,803 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'Brush Script MT' (BRUSHSCI.TTF) italic normal 400 normal>) = 11.05
# 2019-11-10 16:46:00,804 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'Pristina' (PRISTINA.TTF) normal normal 400 normal>) = 10.05
# 2019-11-10 16:46:00,805 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'Book Antiqua' (ANTQUABI.TTF) italic normal book normal>) = 11.05
# 2019-11-10 16:46:00,806 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'Californian FB' (CALIFR.TTF) normal normal 400 normal>) = 10.05
# 2019-11-10 16:46:00,807 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'Cambria' (cambriai.ttf) italic normal 400 normal>) = 11.05
# 2019-11-10 16:46:00,807 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'Berlin Sans FB' (BRLNSB.TTF) normal normal bold normal>) = 10.335
# 2019-11-10 16:46:00,808 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'Adobe Devanagari' (AdobeDevanagari-Regular.otf) normal normal 400 normal>) = 10.05
# 2019-11-10 16:46:00,809 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'Britannic Bold' (BRITANIC.TTF) normal normal bold normal>) = 10.335
# 2019-11-10 16:46:00,811 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: score(<Font 'Bahnschrift' (BAHNSCHRIFT_0.TTF) normal normal 400 normal>) = 10.05
# 2019-11-10 16:46:00,813 DEBUG: matplotlib.font_manager(_findfont_cached): findfont: Matching :family=sans-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0 to DejaVu Sans ('D:\\Python\\Anaconda\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSans.ttf') with score of 0.050000.
# 2019-11-10 16:46:00,817 DEBUG: matplotlib.backends.backend_pdf(fontName): Assigning font /b'F1' = 'D:\\Python\\Anaconda\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSans.ttf'
# 2019-11-10 16:46:00,842 DEBUG: matplotlib.backends.backend_pdf(writeFonts): Embedding font D:\Python\Anaconda\lib\site-packages\matplotlib\mpl-data\fonts\ttf\DejaVuSans.ttf.
# 2019-11-10 16:46:00,844 DEBUG: matplotlib.backends.backend_pdf(writeFonts): Writing TrueType font.

# %% [markdown]
# ## Parameters

# %%
q1 = 0.2098861500
q2 = 0.2455166013
u1 = 2 * np.sqrt(q1) * q2
u2 = np.sqrt(q1) * (1. - 2 * q2)

###Changing params. to params_
#params = batman.TransitParams()
params_t0 =  2458119.72117-2457000                      #time of inferior conjunction
params_per = 1.27492510                      #orbital period
params_rp = 0.12627                      #planet radius (in units of stellar radii)
params_a = 3.835                       #semi-major axis (in units of stellar radii)
params_inc = 87.08                     #orbital inclination (in degrees)
params_ecc = 0.0605                      #eccentricity
params_w = 9.7                       #longitude of periastron (in degrees)
params_u = [u1, u2]                #limb darkening coefficients
params_limb_dark = "quadratic"       #limb darkening model

# According to TESS alert
params_t0 = 1491.9986898
params_a = 3.8083
params_rp = 0.1234

q1 = 0.2098861500
q2 = 0.2455166013
u1 = 2 * np.sqrt(q1) * q2
u2 = np.sqrt(q1) * (1. - 2 * q2)
params_u = [u1, u2]

antiphaseCentred = 0.1 #Change from 0 to something else???

period = params_per * u.day#1.27492510 * u.day
t0 = params_t0 * u.day #(2458119.72117-2457000) * u.day

# %% [markdown]
# ## Median Detrend

# %%
def medianDetrend(lc, windowFactorDurationTransit, returnMedians=False): #remove durationTransitHour
    
    #durationTransit = durationTransitHour / 24.
    window = windowFactorDurationTransit # * durationTransit
    
    t = lc.time / window
    t -= np.amin(t)
    tMax = int(np.ceil(np.amax(t)))
    
    medians = []
    ts = []
    te = []
    for windowStart in range(0, tMax):
        ts.append(windowStart)
        te.append(windowStart+1.)
        currentIds = np.where(np.logical_and(t >= windowStart, t < windowStart+1.))
        median = np.nanmedian(lc.flux[currentIds])
        medians.append(median)
        lc.flux_err[currentIds] /= median        
        lc.flux[currentIds] /= median

    if returnMedians:
        return lc, medians, ts, te, t
    return lc

# %%
#####################################################################################    
#data = Table([lc.time, lc.flux,  lc.flux_err])
#data.write("WASP121-lc.dat", format="ascii.no_header", overwrite=True)    
#####################################################################################
#m = batman.TransitModel(params, modelTime)    #initializes model #BATMAN
#modelFlux = m.light_curve(params)          #calculates light curve #BATMAN
#lcBatman = LightCurve(time=modelTime, flux=modelFlux) #BATMAN
##########################################################################
#logging.debug("{}".format("*" * 100))
#logging.debug("{}".format("*" * 100))

# %% [markdown]
# ## Light Curve

# %%
durations = np.linspace(0.05, 0.2, 15) * u.day
modelTime =np.linspace(1491.5, 1516., 5000)#lc.time# #BATMAN

plt.rc('font', family="Times New Roman")
plt.rc('font', size=14)
fig, axes = plt.subplots(2, 1, figsize=(6, 6))
####fig, axes = plt.subplots(1, 1)
fig.subplots_adjust(hspace=0.3)

# Plot the light curve and best-fit model

lc = medianDetrend(lc, 1, returnMedians=False) ###Questionable

ax = axes[0]
#ax.plot(lc.time, lc.flux, ".", c='lightgrey', ms=3)
#x = np.linspace(lc.time.min(), lc.time.max(), 3*len(lc.time))
    
lcp = lc.bin(5)
ax.errorbar(lcp.time, lcp.flux, yerr=lcp.flux_err, fmt='.', c='k', ms=3)
ax.plot(modelTime, lw=0.75) #BATMAN. Removed modelFlux
ax.set_xlabel("time [days]")
ax.set_ylabel("Normalised flux");
ax.set_xlim([1491, 1516])

# Plot the folded data points
#ax = axes[1]
ax = axes
x = (lc.time * u.day - t0 + antiphaseCentred*period) % period - 0.5*period
m = np.abs(x) < 0.5 * period #*u.day
ax.plot(x[m] / period + 0.5 - antiphaseCentred, lc.flux[m], ".", color="lightgrey", ms=3)
    
lcp = lc.fold(period.value, t0=t0.value+(antiphaseCentred-0.5)*period.value).bin(50)
lct = lcp.time + 0.5 - antiphaseCentred# + antiphaseCentred - 0.5
     
ax.errorbar(lct, lcp.flux, yerr=lcp.flux_err, fmt='.', c='k', ms=3)

fig.savefig(os.path.join(downloadDir, "TIC_92352620_fold.pdf"))

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-9a257e3f36e9> in <module>
#      28 x = (lc.time * u.day - t0 + antiphaseCentred*period) % period - 0.5*period
#      29 m = np.abs(x) < 0.5 * period #*u.day
# ---> 30 ax.plot(x[m] / period + 0.5 - antiphaseCentred, lc.flux[m], ".", color="lightgrey", ms=3)
#      31
#      32 lcp = lc.fold(period.value, t0=t0.value+(antiphaseCentred-0.5)*period.value).bin(50)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'plot'

# %% [markdown]
# ## Light Curve (Folding "In Phase")

# %%
durations = np.linspace(0.05, 0.2, 15) * u.day
modelTime =np.linspace(1491.5, 1516., 5000)#lc.time# #BATMAN

plt.rc('font', family="Times New Roman")
plt.rc('font', size=14)
fig, axes = plt.subplots(1, 1, )
fig.subplots_adjust(hspace=0.3)

# Plot the light curve and best-fit model

phase = (lc.time % period.value) / period.value

lc = medianDetrend(lc, 1, returnMedians=False) ###Questionable

#ax = axes[0]
#ax.plot(lc.time, lc.flux, ".", c='lightgrey', ms=3)
#x = np.linspace(lc.time.min(), lc.time.max(), 3*len(lc.time))
    
lcp = lc#.bin(5)
#ax.errorbar(lcp.time%phase, lcp.flux, yerr=lcp.flux_err, fmt='.', c='k', ms=3)
#ax.plot(modelTime, lw=0.75) #BATMAN. Removed modelFlux
#ax.set_xlabel("time [days]")
#ax.set_ylabel("Normalised flux");
#ax.set_xlim([1491, 1516])


# Plot the folded data points
N=2 #NEW
ax = axes #changed from axes[1] to axes, after removing plt.subplots(2,1,)
x = (lc.time * u.day - t0 + antiphaseCentred*period) % period - 0.5*period
m = np.abs(x) < 0.5 * period #*u.day
ax.plot(x[m] / (period) + 0.5 - antiphaseCentred, lc.flux[m], ".", color="lightgrey", ms=3)
#ax.plot(x[m].value % phase, lc.flux[m], ".", color="lightgrey", ms=3)
ax.grid(b=True, which='minor',  linewidth=.2)
ax.grid(b=True, which='major',  linewidth=1)

#lc = np.where(lc.flux > 1, lc.remove_outliers(3), lc) #NEW
lcp = lc.fold(period.value*N, t0=t0.value+(antiphaseCentred-0.5)*period.value*N).bin(50)
lct = lcp.time + 0.5 - antiphaseCentred  + antiphaseCentred - 0.5

ax.errorbar(lct, lcp.flux, yerr=lcp.flux_err, fmt='.', c='k', ms=3)

fig.savefig(os.path.join(downloadDir, "TIC_92352620_foldinphase.pdf"))

plt.show()

# %% [markdown]
# ## DeltaT Bin

# %%
durations = np.linspace(0.05, 0.2, 15) * u.day
modelTime =np.linspace(1491.5, 1516., 5000)#lc.time# #BATMAN

plt.rc('font', family="Times New Roman")
plt.rc('font', size=14)
fig, axes = plt.subplots(2, 1, figsize=(6, 6))
fig.subplots_adjust(hspace=0.3)

# Plot the light curve and best-fit model

lc = medianDetrend(lc, 1, returnMedians=False) ###Questionable
ax = axes[0]
ax.plot(lc.time, lc.flux, ".", c='lightgrey', ms=3)
x = np.linspace(lc.time.min(), lc.time.max(), 3*len(lc.time))

halfhour = period.value/48 #The periods should be roughly one day
#lcb = lc.bin(round(1/halfhour)) #Inverse gives number greater than one to bin
lcb = lc

ax.errorbar(lcb.time, lcb.flux, yerr=lcb.flux_err, fmt='.', c='k', ms=3)
ax.plot(modelTime, lw=0.75) #BATMAN. Removed modelFlux
ax.set_xlabel("time [days]")
ax.set_ylabel("Normalised flux");
ax.set_xlim([1491, 1516])

# Plot the folded data points
N=2 #NEW
ax = axes[1]
x = (lcb.time * u.day - t0 + antiphaseCentred*period) % period - 0.5*period
m = np.abs(x) < 0.5 * period #*u.day
ax.plot(x[m] / (period) + 0.5 - antiphaseCentred, lcb.flux[m], ".", color="lightgrey", ms=3)

#lc = np.where(lc.flux > 1, lc.remove_outliers(3), lc) #NEW
lcp = lcb.fold(period.value*N, t0=t0.value+(antiphaseCentred-0.5)*period.value).bin(round(1/halfhour))
lct = lcp.time + 0.5 - antiphaseCentred# + antiphaseCentred - 0.5
     
ax.errorbar(lct, lcp.flux, yerr=lcp.flux_err, fmt='.', c='k', ms=3)

#fig.savefig(os.path.join(downloadDir, "TIC_92352620_foldinphase.pdf"))

plt.show()
print(1/halfhour)

# %% [markdown]
# ## Best-Fit Model

# %%
# Over-plot the best fit model
ax.set_xlabel("Phase")
ax.set_ylabel("Normalised flux")
    
xM = (modelTime - params_t0 + antiphaseCentred*params_per) % params_per - 0.5*params_per
m = np.abs(xM) < 0.5 * params_per# *u.day
idsSort = np.argsort(xM[m])
ax.plot(xM[m][idsSort] / params_per + 0.5 - antiphaseCentred, lw=2) #BATMAN, removed ,modelFlux[m][idsSort],
    
#plt.suptitle(target["name"])
    
ax.get_xaxis().set_minor_locator(matplotlib.ticker.AutoMinorLocator())
ax.get_yaxis().set_minor_locator(matplotlib.ticker.AutoMinorLocator())
ax.grid(b=True, which='minor',  linewidth=.2)
ax.grid(b=True, which='major',  linewidth=1)


#####################################################################################################################
    
fig, axes = plt.subplots(nrows=2, ncols=1, sharex=True,
                                   gridspec_kw={'height_ratios': [1, 1]},
                                   figsize=(12, 5.))
fig.set_tight_layout({'rect': [0, 0, 1, 0.98], 'pad': 1., 'h_pad': 0})
    
dataLine = axes[0].plot(lcOri.time, lcOri.flux, '.', c='k', ms=1.5, zorder=0, rasterized=True)
markers, caps, bars = axes[0].errorbar(lcOri.time, lcOri.flux, lcOri.flux_err, fmt='o', c='g', ms=1., zorder=0, rasterized=True, capthick=0)
[bar.set_alpha(0.1) for bar in bars]
axes[0].set_ylabel("Normalized flux")
  
axes[0].get_xaxis().set_minor_locator(matplotlib.ticker.AutoMinorLocator())
axes[0].get_yaxis().set_minor_locator(matplotlib.ticker.AutoMinorLocator())
axes[0].grid(b=True, which='minor', linewidth=.2)
axes[0].grid(b=True, which='major', linewidth=1)
axes[0].text(0.02, 0.005, 'TESS PDC-corrected SAP photometry',verticalalignment='bottom', horizontalalignment='left',transform=axes[0].transAxes, ) #fontsize=15)
#axes[0].set_ylim([0.978, 1.005])

lcflux_red = np.where(lc.flux > 1.005, 1, lc.flux)
dataLine = axes[1].plot(lc.time, lcflux_red, '.', c='k', ms=1.5, zorder=0, rasterized=True)
markers, caps, bars = axes[1].errorbar(lc.time, lcflux_red, lc.flux_err, fmt='o', c='b', ms=1., zorder=0, rasterized=True, capthick=0)
[bar.set_alpha(0.1) for bar in bars]
axes[1].set_ylabel("Normalized flux")
    
axes[1].get_xaxis().set_minor_locator(matplotlib.ticker.AutoMinorLocator())
axes[1].get_yaxis().set_minor_locator(matplotlib.ticker.AutoMinorLocator())
axes[1].grid(b=True, which='minor', linewidth=.2)
axes[1].grid(b=True, which='major', linewidth=1)
axes[1].set_xlabel("Epoch (BJD$_\mathrm{TDB}$ - 2457000)")
axes[1].text(0.02, 0.005, 'Corrected flux',verticalalignment='bottom', horizontalalignment='left',transform=axes[1].transAxes, ) #fontsize=15)
axes[1].set_xlim([1339, 1354])
#axes[1].set_ylim([0.978, 1.005])
fig.savefig(os.path.join(downloadDir, "TIC_92352620_bestfit.pdf"))

plt.show()

# %%
time = max(lc.time)-min(lc.time)
time

# %%
time = max(lc.time)-min(lc.time)
lcTransit = lc.copy()
def gridfreq(day,N=10):
    grids=[]
    phases=[]
    for i in np.arange(1/4.2, 1/3.8, (1/time * 1/N)): #p 3.8 to 4.2
        period = 1/i
        phase = (lc.time % period)
        plt.scatter(phase, (lcTransit.flux-1.)*1e6, marker=".", color="k", s=3)
        plt.title("Folded at {} day".format(period))
        plt.xlabel("Phase")
        plt.ylabel("Difference to normalized flux [ppm]")
        plt.show()
        grids.append(grid)
        phases.append(phase)
    return grids

gridfreq(1)

# %%
time = max(lc.time)-min(lc.time)
lcTransit = lc.copy()
def gridfreq(day,N=10):
    grids=[]
    phases=[]
    for i in np.arange(1/4.2, 1/3.8, (1/time * 1/N)): #p 3.8 to 4.2
        period = 1/i
        phase = (lc.time % period) 
        lcTransit = lc.remove_outliers(sigma_upper=3, sigma_lower=float('inf'))
        #plt.scatter(phase, (lcTransit.flux-1.)*1e6, marker=".", color="k", s=3)
        #plt.title("Folded at {} day".format(period))
        #plt.xlabel("Phase")
        #plt.ylabel("Difference to normalized flux [ppm]")
        #plt.show()
        grids.append(grid)
        phases.append(phase)
    return grids, phases

gridfreq(1)

# %%
gridfreq(1)[1][4]

# %%
def weightmean(ph, dt=0.5):
    return np.mean(ph, axis=dt)

period = gridfreq(1)[1][4]
phase = lc.time % period
weightmean(phase)

# %%
# Look at the 1.13 d stellar rotation Period
#params_per2 = 1.27492510
#params_per = 2.27492510
params_per = 3.95
lcTransitRemoved = lc.copy()

#params_per = 3.47492510 
phase = (lc.time % params_per) #OBS TIME MOD PERIOD TIME 
#fold_time = (((lcTransitRemoved.time - phase * params_per) / params_per) % 1)
#fold_time[fold_time > 0.5] -= 1
#idsNan = np.abs(fold_time) < 0.05
#lcTransitRemoved.flux[idsNan] = np.nan
#idsNan = np.logical_and(fold_time < 0.55, fold_time > 0.45)
#lcTransitRemoved.flux[idsNan] = np.nan
#lcTransitRemoved.remove_nans()
#np.savetxt(os.path.join(downloadDir, "TIC-lcTransitRemoved.dat"), np.array([lcTransitRemoved.time, lcTransitRemoved.flux, lcTransitRemoved.flux_err]).T)

lcTransitRemovedFolded = lcTransitRemoved#.fold(phase)

plt.figure()
plt.scatter(lcTransitRemovedFolded.time, (lcTransitRemovedFolded.flux-1.)*1e6, marker=".", color="k", s=3)
plt.title("Unfolded light curve")
plt.figure()
plt.scatter(phase, (lcTransitRemovedFolded.flux-1.)*1e6, marker=".", color="k", s=3)
lcTransitRemovedFoldedBinned = lcTransitRemovedFolded.bin(500)
        
#plt.errorbar(phase, (lcTransitRemovedFoldedBinned.flux-1.)*1e6, yerr=lcTransitRemovedFoldedBinned.flux_err*1e6, fmt='.', c='k', ms=3)
plt.title("Folded at {} day".format(params_per))
plt.xlabel("Phase")
plt.ylabel("Difference to normalized flux [ppm]")

#BIN
lcTransitRemovedFolded = lcTransitRemoved.bin(10)
#phase = np.digitize(phase, 10)
plt.figure()
plt.scatter(lcTransitRemovedFolded.time, (lcTransitRemovedFolded.flux-1.)*1e6, marker=".", color="k", s=3)
#plt.scatter(gridfreq(1.27), (lcTransitRemovedFolded.flux-1.)*1e6, marker=".", color="k", s=3)
#plt.scatter(phase, (lcTransitRemovedFolded.flux-1.)*1e6, marker=".", color="k", s=3)
lcTransitRemovedFoldedBinned = lcTransitRemovedFolded.bin(500)
        
#plt.errorbar(lcTransitRemovedFolded.time, (lcTransitRemovedFoldedBinned.flux-1.)*1e6, yerr=lcTransitRemovedFoldedBinned.flux_err*1e6, fmt='.', c='k', ms=3)
plt.title("Folded and binned at {} day".format(params_per))
plt.xlabel("Phase")
plt.ylabel("Difference to normalised flux [ppm]")

print(gridfreq(1.27))
plt.show()

# %%
lcTransitRemovedFolded = lcTransitRemoved.bin(10)
#phase = np.digitize(phase, 10)
plt.figure()
plt.scatter(lcTransitRemovedFolded.time, (lcTransitRemovedFolded.flux-1.)*1e6, marker=".", color="grey", s=3)
#plt.scatter(phase, (lcTransitRemovedFolded.flux-1.)*1e6, marker=".", color="grey", s=3)
lcTransitRemovedFoldedBinned = lcTransitRemovedFolded.bin(500)
        
#plt.errorbar(lcTransitRemovedFolded.time, (lcTransitRemovedFoldedBinned.flux-1.)*1e6, yerr=lcTransitRemovedFoldedBinned.flux_err*1e6, fmt='.', c='k', ms=3)
plt.title("Folded at {} day".format(params_per))
plt.xlabel("Phase")
plt.ylabel("Difference to normalised flux [ppm]")

plt.show()

# %%
len(phase)

# %% [markdown]
# ## Removal of Outliers

# %%
print(lcTransitRemovedFolded.flux-1)

# %%
##Remove positive outliers
print('Maximum before outlier removal:',max(lcTransitRemovedFolded.flux-1)*1e6)
maxi = max(lcTransitRemovedFolded.flux-1)*1e6
NormFluxDiff = lcTransitRemovedFolded.flux-1
NormFluxDiff = np.where(NormFluxDiff*1e6 > maxi-(maxi/2), 0, NormFluxDiff)
print('Maximum after outlier removal:',max(NormFluxDiff)*1e6)

plt.figure()
plt.scatter(lcTransitRemovedFolded.time, (NormFluxDiff)*1e6, marker=".", color="grey", s=3)
lcTransitRemovedFoldedBinned = lcTransitRemovedFolded.bin(500)
        
plt.errorbar(lcTransitRemovedFoldedBinned.time, (lcTransitRemovedFoldedBinned.flux-1.)*1e6, yerr=lcTransitRemovedFoldedBinned.flux_err*1e6, fmt='.', c='k', ms=3)
plt.title("Folded at {} day (without outliers)".format(periodSec))
plt.xlabel("Phase")
plt.ylabel("Difference to normalised flux [ppm]")
fig.savefig(os.path.join(downloadDir, "TIC_92352620_noout2.pdf"))

plt.show()

# %% [markdown]
# ## TBD

# %% [markdown]
# ## One Loop
